# %%
from PIL import Image   
from PIL import *

import matplotlib.pyplot as plt

# %%
image = Image.open('/workspaces/Graficaci-n/img/frieren.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>
